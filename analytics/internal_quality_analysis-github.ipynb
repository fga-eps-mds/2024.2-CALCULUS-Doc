# %% [markdown]
# # Analytics - Product Quality - GitHub
#
# #### Date: 2024/02
#
# #### SUMMARY:
#
# - This notebook represents the project quality analysis of the date exposed right above.
#
# ### TEAM:
#
# ##### Semester: 2024/02
# ##### Professor: Hilmer Neri
#
# ##### Members:
#
# - Member x
# - Member y

# %% [markdown]
# ### LIBRARIES

# %%
# Deal with data
import pandas as pd
import json
from glob import glob
import os

# Deal with visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Deal with type hints
from typing import List

# Deal with time
import datetime

# %% [markdown]
# ### GRAPH SETTINGS

# %%
# %config InlineBackend.figure_format ='retina'
sns.set(font_scale=1.5)
sns.set_style('darkgrid',
              {'xtick.bottom' : True,
               'ytick.left': True,
               'grid.linestyle':'--',
               'font.monospace': ['Computer Modern Typewriter'],
               'axes.edgecolor' : 'white'})

# %% [markdown]
# ### DATAFRAME SETTINGS

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# #### Replace your repository names

# %%
# Add your repos here
# Example: ['YourRepoName_1', 'YourRepoName_2']
repos_project = ['APP', 'StudioMaker', 'UserService', 'Frontend']

# %% [markdown]
# #### Replace your build workflow .yml file name

# %%
# Set your build workflow .yml name
# Example: build.yml -> build
build_yml_name = "code-analysis"

# %% [markdown]
# #### Filter dates - Workflow Runs

# %%
# Set the dates you want to filter the analysis of workflow runs
# Example: start_date_workflow_runs = "2024-09-01"
#          end_date_workflow_runs = "2024-09-05"
start_date_workflow_runs = "2024-10-15" # to get all dates: "1999-01-01"
end_date_workflow_runs = "2025-02-20"   # to get all dates: "2199-01-01"

# %% [markdown]
# #### Filter dates - Team Throughput

# %%
# Set the dates you want to filter the analysis of issues
# Example: start_date_issues = "2024-09-01"
#          end_date_issues = "2024-09-05"
start_date_issues = "2024-10-15" # to get all dates: "1999-01-01"
end_date_issues = "2025-02-20"   # to get all dates: "2199-01-01"
### GitHub
##### Path to the folder with all your jsons

# %%
data_runs = glob('../analytics-raw-data/GitHub_API-Runs-fga-eps-mds-*.json')
data_issues = glob('../analytics-raw-data/GitHub_API-Issues-fga-eps-mds-*.json')

# %% [markdown]
# # Create Workflow Runs DataFrame

# %% [markdown]
# #### Unmarshall json

# %%
def unmarshall(json_path: str) -> dict:
    with open(json_path) as json_file:
        json_obj = json.load(json_file)
    return json_obj

# %% [markdown]
# #### Extract Workflow Runs Data

# %%
def get_workflow_data():
    table_data = []
    for json_path in data_runs:
        dados = unmarshall(json_path)
        for run in dados["workflow_runs"]:
            updated_at = datetime.datetime.strptime(run["updated_at"], "%Y-%m-%dT%H:%M:%SZ")
            created_at = datetime.datetime.strptime(run["created_at"], "%Y-%m-%dT%H:%M:%SZ")
            feedback_time = (updated_at - created_at).total_seconds()
            
            workflow_id = run["id"]
            conclusion = run["conclusion"]
            author = run["actor"]["login"]
            workflow_yml_name = run["path"].split("/")[-1][:-4]

            repo = run["repository"]["name"].split("-")[-1]

            table_data.append({
                "Workflow_run ID": workflow_id,
                "Conclusion": conclusion,
                "Author": author,
                "Created at": created_at,
                "Updated at": updated_at,
                "Feedback Time": feedback_time,
                "Workflow .YML Name": workflow_yml_name,
                "Repository Name": repo
            })
    print(table_data)
    return table_data

# %% [markdown]
# #### Generate Workflow Runs DataFrame

# %%
def generate_workflow_runs_df(data: List[dict]) -> pd.DataFrame:
    df = pd.DataFrame(data)

    return df

# %%
workflow_run_df = generate_workflow_runs_df(get_workflow_data())
workflow_run_df.tail()
# Out:
# [{'Workflow_run ID': 12130137774, 'Conclusion': None, 'Author': 'gabrielm2q', 'Created at': datetime.datetime(2024, 12, 2, 23, 56, 32), 'Updated at': datetime.datetime(2024, 12, 2, 23, 56, 40), 'Feedback Time': 8.0, 'Workflow .YML Name': 'code-analysis', 'Repository Name': 'APP'}, {'Workflow_run ID': 12130137773, 'Conclusion': None, 'Author': 'gabrielm2q', 'Created at': datetime.datetime(2024, 12, 2, 23, 56, 32), 'Updated at': datetime.datetime(2024, 12, 2, 23, 56, 42), 'Feedback Time': 10.0, 'Workflow .YML Name': 'metrics', 'Repository Name': 'APP'}, {'Workflow_run ID': 12129820402, 'Conclusion': 'success', 'Author': 'dartmol203', 'Created at': datetime.datetime(2024, 12, 2, 23, 27, 25), 'Updated at': datetime.datetime(2024, 12, 2, 23, 29), 'Feedback Time': 95.0, 'Workflow .YML Name': 'code-analysis', 'Repository Name': 'APP'}, {'Workflow_run ID': 12125689051, 'Conclusion': 'success', 'Author': 'Joao151104', 'Created at': datetime.datetime(2024, 12, 2, 18, 32, 30), 'Updated at': datetime.datetime(2024, 12, 2, 18, 33, 56), 'Feedback Time': 86.0, 'Workflow .YML Name': 'code-analysis', 'Repository Name': 'APP'}, {'Workflow_run ID': 12111953258, 'Conclusion': 'success', 'Author': 'dartmol203', 'Created at': datetime.datetime(2024, 12, 2, 3, 11, 45), 'Updated at': datetime.datetime(2024, 12, 2, 3, 12, 10), 'Feedback Time': 25.0, 'Workflow .YML Name': 'metrics', 'Repository Name': 'APP'}, {'Workflow_run ID': 12111953248, 'Conclusion': 'success', 'Author': 'dartmol203', 'Created at': datetime.datetime(2024, 12, 2, 3, 11, 45), 'Updated at': datetime.datetime(2024, 12, 2, 3, 13, 25), 'Feedback Time': 100.0, 'Workflow .YML Name': 'code-analysis', 'Repository Name': 'APP'}, {'Workflow_run ID': 12111935819, 'Conclusion': 'success', 'Author': 'dartmol203', 'Created at': datetime.datetime(2024, 12, 2, 3, 9, 42), 'Updated at': datetime.datetime(2024, 12, 2, 3, 11, 12), 'Feedback Time': 90.0, 'Workflow .YML Name': 'code-analysis', 'Repository Name': 'APP'}, {'Workflow_run ID': 12111880080, 'Conclusion': 'failure', 'Author': 'dartmol203', 'Created at': datetime.datetime(2024, 12, 2, 3, 3, 25), 'Updated at': datetime.datetime(2024, 12, 2, 3, 4, 37), 'Feedback Time': 72.0, 'Workflow .YML Name': 'code-analysis', 'Repository Name': 'APP'}, {'Workflow_run ID': 12111850631, 'Conclusion': 'failure', 'Author': 'dartmol203', 'Created at': datetime.datetime(2024, 12, 2, 3, 0, 12), 'Updated at': datetime.datetime(2024, 12, 2, 3, 1, 13), 'Feedback Time': 61.0, 'Workflow .YML Name': 'code-analysis', 'Repository Name': 'APP'}, {'Workflow_run ID': 12111828584, 'Conclusion': 'failure', 'Author': 'dartmol203', 'Created at': datetime.datetime(2024, 12, 2, 2, 57, 50), 'Updated at': datetime.datetime(2024, 12, 2, 2, 58, 51), 'Feedback Time': 61.0, 'Workflow .YML Name': 'code-analysis', 'Repository Name': 'APP'}, {'Workflow_run ID': 12111746081, 'Conclusion': 'failure', 'Author': 'dartmol203', 'Created at': datetime.datetime(2024, 12, 2, 2, 48, 54), 'Updated at': datetime.datetime(2024, 12, 2, 2, 50, 5), 'Feedback Time': 71.0, 'Workflow .YML Name': 'code-analysis', 'Repository Name': 'APP'}, {'Workflow_run ID': 12111713627, 'Conclusion': 'failure', 'Author': 'dartmol203', 'Created at': datetime.datetime(2024, 12, 2, 2, 45, 22), 'Updated at': datetime.datetime(2024, 12, 2, 2, 46, 32), 'Feedback Time': 70.0, 'Workflow .YML Name': 'code-analysis', 'Repository Name': 'APP'}, {'Workflow_run ID': 12111690155, 'Conclusion': 'failure', 'Author': 'dartmol203', 'Created at': datetime.datetime(2024, 12, 2, 2, 42, 51), 'Updated at': datetime.datetime(2024, 12, 2, 2, 44, 6), 'Feedback Time': 75.0, 'Workflow .YML Name': 'code-analysis', 'Repository Name': 'APP'}, {'Workflow_run ID': 12111601281, 'Conclusion': 'failure', 'Author': 'dartmol203', 'Created at': datetime.datetime(2024, 12, 2, 2, 33, 29), 'Updated at': datetime.datetime(2024, 12, 2, 2, 37, 37), 'Feedback Time': 248.0, 'Workflow .YML Name': 'code-analysis', 'Repository Name': 'APP'}, {'Workflow_run ID': 12111508039,  ...
#      Workflow_run ID Conclusion      Author          Created at  \
# 418      11903621379    success  gabrielm2q 2024-11-19 00:19:18
# 419      11903557045    success  dartmol203 2024-11-19 00:14:21
# 420      11903319653    failure  gabrielm2q 2024-11-18 23:53:43
# 421      11903135101    success  dartmol203 2024-11-18 23:36:59
# 422      11903088090    success  dartmol203 2024-11-18 23:33:05
#
#              Updated at  Feedback Time Workflow .YML Name Repository Name
# 418 2024-11-19 00:19:35           17.0            metrics             APP
# 419 2024-11-19 00:18:46          265.0      code-analysis             APP
# 420 2024-11-18 23:53:56           13.0            metrics             APP
# 421 2024-11-18 23:41:38          279.0      code-analysis             APP
# 422 2024-11-18 23:37:49          284.0      code-analysis             APP

# %% [markdown]
# ### Create dataframe per repository

# %%
repos_dataframes = []

for repo in repos_project:
    dataframe = workflow_run_df[workflow_run_df['Repository Name'] == repo]
    repos_dataframes.append({'name': repo, 'df': dataframe})

# %%
repos_dataframes
# Out:
# [{'name': 'APP',
#   'df':      Workflow_run ID Conclusion      Author          Created at  \
#   0        12130137774       None  gabrielm2q 2024-12-02 23:56:32
#   1        12130137773       None  gabrielm2q 2024-12-02 23:56:32
#   2        12129820402    success  dartmol203 2024-12-02 23:27:25
#   3        12125689051    success  Joao151104 2024-12-02 18:32:30
#   24  2024-12-02 00:50:11           24.0            metrics             APP
#   25  2024-12-02 00:54:29          282.0      code-analysis             APP
#   26  2024-12-02 00:48:34          287.0      code-analysis             APP
#   27  2024-12-02 00:25:32           21.0            metrics             APP
#   28  2024-12-02 00:29:47          276.0      code-analysis             APP
#   29  2024-12-02 00:22:01          285.0      code-analysis             APP
#   30  2024-12-02 00:13:31           72.0      code-analysis             APP
#   31  2024-12-02 00:06:46          272.0      code-analysis             APP
#   32  2024-12-01 23:49:45          274.0      code-analysis             APP
#   33  2024-12-01 23:45:33           22.0            metrics             APP
#   34  2024-12-01 23:44:44          271.0      code-analysis             APP
#   35  2024-12-01 23:35:29           13.0            metrics             APP
#   36  2024-12-01 23:39:47          271.0      code-analysis             APP
#   37  2024-12-01 23:34:16          267.0      code-analysis             APP
#   38  2024-12-01 21:50:03          265.0      code-analysis             APP
#   39  2024-12-01 21:34:43           12.0            metrics             APP
#   40  2024-12-01 21:39:07          276.0      code-analysis             APP
#   41  2024-12-01 21:24:35          272.0      code-analysis             APP
#   42  2024-12-01 21:21:33          266.0      code-analysis             APP
#   43  2024-12-01 21:09:14          274.0      code-analysis             APP
#   44  2024-11-19 00:19:35           17.0            metrics             APP
#   45  2024-11-19 00:18:46          265.0      code-analysis             APP
#   46  2024-11-18 23:53:56           13.0            metrics             APP
#   47  2024-11-18 23:41:38          279.0      code-analysis             APP
#   48  2024-11-18 23:37:49          284.0      code-analysis             APP
#   49  2024-12-02 03:11:53            8.0            metrics             APP
#   50  2024-12-02 03:11:53            8.0      code-analysis             APP
#   51  2024-12-02 03:11:12           90.0      code-analysis             APP
#   52  2024-12-02 03:04:37           72.0      code-analysis             APP
#   53  2024-12-02 03:01:13           61.0      code-analysis             APP
#   54  2024-12-02 02:58:51           61.0      code-analysis             APP
#   55  2024-12-02 02:50:05           71.0      code-analysis             APP
#   56  2024-12-02 02:46:32           70.0      code-analysis             APP
#   57  2024-12-02 02:44:06           75.0      code-analysis             APP
#   58  2024-12-02 02:37:37          248.0      code-analysis             APP
#   59  2024-12-02 02:24:18           21.0            metrics             APP
#   60  2024-12-02 02:28:22          266.0      code-analysis             APP
#   61  2024-12-02 02:28:14          268.0      code-analysis             APP
#   62  2024-12-02 02:20:12          279.0      code-analysis             APP
#   63  2024-12-02 01:52:19           21.0            metrics             APP
#   64  2024-12-02 02:02:02          604.0      code-analysis             APP
#   65  2024-12-02 01:50:59          273.0      code-analysis             APP
#   66  2024-12-02 01:35:39         1299.0            metrics             APP
#   67  2024-12-02 01:33:32         1172.0      code-analysis             APP
#   68  2024-12-02 01:11:46          279.0      code-analysis             APP
#   69  2024-12-02 00:50:11           24.0            metrics             APP
#   70  2024-12-02 00:54:29          282.0      code-analysis             APP
#   71  2024-12-02 00:48:34          287.0      code-analysis             APP
#   72  2024-12-02 00:25:32           21.0            metrics             APP
#   73  2024-12-02 00:29:47          276.0      code-analysis             APP
#   74  2024-12-02 00:22:01          285.0      code-analysis             APP
#   75  2024-12-02 00:13:31           72.0      code-analysis             APP
#   76  2024-12-02 00:06:46          272.0      code-analysis             APP
#   77  2024-12-01 23:49:45          274.0      code-analysis             APP
#   78  2024-12-01 23:45:33           22.0            metrics             APP
#   79  2024-12-01 23:44:44          271.0      code-analysis             APP
#   80  2024-12-01 23:35:29           13.0            metrics             APP
#   81  2024-12-01 23:39:47          271.0      code-analysis             APP
#   82  2024-12-01 23:34:16          267.0      code-analysis             APP
#   83  2024-12-01 21:50:03          265.0      code-analysis             APP
#   84  2024-12-01 21:34:43           12.0            metrics             APP
#   85  2024-12-01 21:39:07          276.0      code-analysis             APP
#   86  2024-12-01 21:24:35          272.0      code-analysis             APP
#   87  2024-12-01 21:21:33          266.0      code-analysis             APP
#   88  2024-12-01 21:09:14          274.0      code-analysis             APP
#   89  2024-11-19 00:19:35           17.0            metrics             APP
#   90  2024-11-19 00:18:46          265.0      code-analysis             APP
#   91  2024-11-18 23:53:56           13.0            metrics             APP
#   92  2024-11-18 23:41:38          279.0      code-analysis             APP
#   93  2024-11-18 23:37:49          284.0      code-analysis             APP
#   143 2024-12-02 01:52:06            8.0            metrics             APP
#   144 2024-12-02 01:52:06            8.0      code-analysis             APP
#   145 2024-12-02 01:50:59          273.0      code-analysis             APP
#   146 2024-12-02 01:35:39         1299.0            metrics             APP
#   147 2024-12-02 01:33:32         1172.0      code-analysis             APP
#   148 2024-12-02 01:11:46          279.0      code-analysis             APP
#   149 2024-12-02 00:50:11           24.0            metrics             APP
#   150 2024-12-02 00:54:29          282.0      code-analysis             APP
#   151 2024-12-02 00:48:34          287.0      code-analysis             APP
#   152 2024-12-02 00:25:32           21.0            metrics             APP
#   153 2024-12-02 00:29:47          276.0      code-analysis             APP
#   154 2024-12-02 00:22:01          285.0      code-analysis             APP
#   155 2024-12-02 00:13:31           72.0      code-analysis             APP
#   156 2024-12-02 00:06:46          272.0      code-analysis             APP
#   157 2024-12-01 23:49:45          274.0      code-analysis             APP
#   158 2024-12-01 23:45:33           22.0            metrics             APP
#   159 2024-12-01 23:44:44          271.0      code-analysis             APP
#   160 2024-12-01 23:35:29           13.0            metrics             APP
#   161 2024-12-01 23:39:47          271.0      code-analysis             APP
#   162 2024-12-01 23:34:16          267.0      code-analysis             APP
#   163 2024-12-01 21:50:03          265.0      code-analysis             APP
#   164 2024-12-01 21:34:43           12.0            metrics             APP
#   165 2024-12-01 21:39:07          276.0      code-analysis             APP
#   166 2024-12-01 21:24:35          272.0      code-analysis             APP
#   167 2024-12-01 21:21:33          266.0      code-analysis             APP
#   168 2024-12-01 21:09:14          274.0      code-analysis             APP
#   169 2024-11-19 00:19:35           17.0            metrics             APP
#   170 2024-11-19 00:18:46          265.0      code-analysis             APP
#   171 2024-11-18 23:53:56           13.0            metrics             APP
#   172 2024-11-18 23:41:38          279.0      code-analysis             APP
#   173 2024-11-18 23:37:49          284.0      code-analysis             APP
#   174 2024-12-02 01:14:08            8.0            metrics             APP
#   175 2024-12-02 01:14:08            8.0      code-analysis             APP
#   176 2024-12-02 01:11:46          279.0      code-analysis             APP
#   177 2024-12-02 00:50:11           24.0            metrics             APP
#   178 2024-12-02 00:54:29          282.0      code-analysis             APP
#   179 2024-12-02 00:48:34          287.0      code-analysis             APP
#   180 2024-12-02 00:25:32           21.0            metrics             APP
#   181 2024-12-02 00:29:47          276.0      code-analysis             APP
#   182 2024-12-02 00:22:01          285.0      code-analysis             APP
#   183 2024-12-02 00:13:31           72.0      code-analysis             APP
#   184 2024-12-02 00:06:46          272.0      code-analysis             APP
#   185 2024-12-01 23:49:45          274.0      code-analysis             APP
#   186 2024-12-01 23:45:33           22.0            metrics             APP
#   187 2024-12-01 23:44:44          271.0      code-analysis             APP
#   188 2024-12-01 23:35:29           13.0            metrics             APP
#   189 2024-12-01 23:39:47          271.0      code-analysis             APP
#   190 2024-12-01 23:34:16          267.0      code-analysis             APP
#   191 2024-12-01 21:50:03          265.0      code-analysis             APP
#   192 2024-12-01 21:34:43           12.0            metrics             APP
#   193 2024-12-01 21:39:07          276.0      code-analysis             APP
#   194 2024-12-01 21:24:35          272.0      code-analysis             APP
#   195 2024-12-01 21:21:33          266.0      code-analysis             APP
#   196 2024-12-01 21:09:14          274.0      code-analysis             APP
#   197 2024-11-19 00:19:35           17.0            metrics             APP
#   198 2024-11-19 00:18:46          265.0      code-analysis             APP
#   199 2024-11-18 23:53:56           13.0            metrics             APP
#   200 2024-11-18 23:41:38          279.0      code-analysis             APP
#   201 2024-11-18 23:37:49          284.0      code-analysis             APP
#   202 2024-12-02 01:35:26         1286.0            metrics             APP
#   203 2024-12-02 01:33:32         1172.0      code-analysis             APP
#   204 2024-12-02 01:11:46          279.0      code-analysis             APP
#   205 2024-12-02 00:50:11           24.0            metrics             APP
#   206 2024-12-02 00:54:29          282.0      code-analysis             APP
#   207 2024-12-02 00:48:34          287.0      code-analysis             APP
#   208 2024-12-02 00:25:32           21.0            metrics             APP
#   209 2024-12-02 00:29:47          276.0      code-analysis             APP
#   210 2024-12-02 00:22:01          285.0      code-analysis             APP
#   211 2024-12-02 00:13:31           72.0      code-analysis             APP
#   212 2024-12-02 00:06:46          272.0      code-analysis             APP
#   213 2024-12-01 23:49:45          274.0      code-analysis             APP
#   214 2024-12-01 23:45:33           22.0            metrics             APP
#   215 2024-12-01 23:44:44          271.0      code-analysis             APP
#   216 2024-12-01 23:35:29           13.0            metrics             APP
#   217 2024-12-01 23:39:47          271.0      code-analysis             APP
#   218 2024-12-01 23:34:16          267.0      code-analysis             APP
#   219 2024-12-01 21:50:03          265.0      code-analysis             APP
#   220 2024-12-01 21:34:43           12.0            metrics             APP
#   221 2024-12-01 21:39:07          276.0      code-analysis             APP
#   222 2024-12-01 21:24:35          272.0      code-analysis             APP
#   223 2024-12-01 21:21:33          266.0      code-analysis             APP
#   224 2024-12-01 21:09:14          274.0      code-analysis             APP
#   225 2024-11-19 00:19:35           17.0            metrics             APP
#   226 2024-11-19 00:18:46          265.0      code-analysis             APP
#   227 2024-11-18 23:53:56           13.0            metrics             APP
#   228 2024-11-18 23:41:38          279.0      code-analysis             APP
#   229 2024-11-18 23:37:49          284.0      code-analysis             APP
#   230 2024-12-02 00:25:17            6.0            metrics             APP
#   231 2024-12-02 00:25:18            7.0      code-analysis             APP
#   232 2024-12-02 00:22:01          285.0      code-analysis             APP
#   233 2024-12-02 00:13:31           72.0      code-analysis             APP
#   234 2024-12-02 00:06:46          272.0      code-analysis             APP
#   235 2024-12-01 23:49:45          274.0      code-analysis             APP
#   236 2024-12-01 23:45:33           22.0            metrics             APP
#   237 2024-12-01 23:44:44          271.0      code-analysis             APP
#   238 2024-12-01 23:35:29           13.0            metrics             APP
#   239 2024-12-01 23:39:47          271.0      code-analysis             APP
#   240 2024-12-01 23:34:16          267.0      code-analysis             APP
#   241 2024-12-01 21:50:03          265.0      code-analysis             APP
#   242 2024-12-01 21:34:43           12.0            metrics             APP
#   243 2024-12-01 21:39:07          276.0      code-analysis             APP
#   244 2024-12-01 21:24:35          272.0      code-analysis             APP
#   245 2024-12-01 21:21:33          266.0      code-analysis             APP
#   246 2024-12-01 21:09:14          274.0      code-analysis             APP
#   247 2024-11-19 00:19:35           17.0            metrics             APP
#   248 2024-11-19 00:18:46          265.0      code-analysis             APP
#   249 2024-11-18 23:53:56           13.0            metrics             APP
#   250 2024-11-18 23:41:38          279.0      code-analysis             APP
#   251 2024-11-18 23:37:49          284.0      code-analysis             APP
#   252 2024-12-02 00:49:55            8.0            metrics             APP
#   253 2024-12-02 00:49:55            8.0      code-analysis             APP
#   254 2024-12-02 00:48:34          287.0      code-analysis             APP
#   255 2024-12-02 00:25:32           21.0            metrics             APP
#   256 2024-12-02 00:29:47          276.0      code-analysis             APP
#   257 2024-12-02 00:22:01          285.0      code-analysis             APP
#   258 2024-12-02 00:13:31           72.0      code-analysis             APP
#   259 2024-12-02 00:06:46          272.0      code-analysis             APP
#   260 2024-12-01 23:49:45          274.0      code-analysis             APP
#   261 2024-12-01 23:45:33           22.0            metrics             APP
#   262 2024-12-01 23:44:44          271.0      code-analysis             APP
#   263 2024-12-01 23:35:29           13.0            metrics             APP
#   264 2024-12-01 23:39:47          271.0      code-analysis             APP
#   265 2024-12-01 23:34:16          267.0      code-analysis             APP
#   266 2024-12-01 21:50:03          265.0      code-analysis             APP
#   267 2024-12-01 21:34:43           12.0            metrics             APP
#   268 2024-12-01 21:39:07          276.0      code-analysis             APP
#   269 2024-12-01 21:24:35          272.0      code-analysis             APP
#   270 2024-12-01 21:21:33          266.0      code-analysis             APP
#   271 2024-12-01 21:09:14          274.0      code-analysis             APP
#   272 2024-11-19 00:19:35           17.0            metrics             APP
#   273 2024-11-19 00:18:46          265.0      code-analysis             APP
#   274 2024-11-18 23:53:56           13.0            metrics             APP
#   275 2024-11-18 23:41:38          279.0      code-analysis             APP
#   276 2024-11-18 23:37:49          284.0      code-analysis             APP
#   327 2024-12-02 02:24:04            7.0            metrics             APP
#   328 2024-12-02 02:24:02            6.0      code-analysis             APP
#   329 2024-12-02 02:23:52            6.0      code-analysis             APP
#   330 2024-12-02 02:20:12          279.0      code-analysis             APP
#   331 2024-12-02 01:52:19           21.0            metrics             APP
#   332 2024-12-02 02:02:02          604.0      code-analysis             APP
#   333 2024-12-02 01:50:59          273.0      code-analysis             APP
#   334 2024-12-02 01:35:39         1299.0            metrics             APP
#   335 2024-12-02 01:33:32         1172.0      code-analysis             APP
#   336 2024-12-02 01:11:46          279.0      code-analysis             APP
#   337 2024-12-02 00:50:11           24.0            metrics             APP
#   338 2024-12-02 00:54:29          282.0      code-analysis             APP
#   339 2024-12-02 00:48:34          287.0      code-analysis             APP
#   340 2024-12-02 00:25:32           21.0            metrics             APP
#   341 2024-12-02 00:29:47          276.0      code-analysis             APP
#   342 2024-12-02 00:22:01          285.0      code-analysis             APP
#   343 2024-12-02 00:13:31           72.0      code-analysis             APP
#   344 2024-12-02 00:06:46          272.0      code-analysis             APP
#   345 2024-12-01 23:49:45          274.0      code-analysis             APP
#   346 2024-12-01 23:45:33           22.0            metrics             APP
#   347 2024-12-01 23:44:44          271.0      code-analysis             APP
#   348 2024-12-01 23:35:29           13.0            metrics             APP
#   349 2024-12-01 23:39:47          271.0      code-analysis             APP
#   350 2024-12-01 23:34:16          267.0      code-analysis             APP
#   351 2024-12-01 21:50:03          265.0      code-analysis             APP
#   352 2024-12-01 21:34:43           12.0            metrics             APP
#   353 2024-12-01 21:39:07          276.0      code-analysis             APP
#   354 2024-12-01 21:24:35          272.0      code-analysis             APP
#   355 2024-12-01 21:21:33          266.0      code-analysis             APP
#   356 2024-12-01 21:09:14          274.0      code-analysis             APP
#   357 2024-11-19 00:19:35           17.0            metrics             APP
#   358 2024-11-19 00:18:46          265.0      code-analysis             APP
#   359 2024-11-18 23:53:56           13.0            metrics             APP
#   360 2024-11-18 23:41:38          279.0      code-analysis             APP
#   361 2024-11-18 23:37:49          284.0      code-analysis             APP
#   406 2024-12-01 23:45:19            8.0      code-analysis             APP
#   407 2024-12-01 23:45:19            8.0            metrics             APP
#   408 2024-12-01 23:44:44          271.0      code-analysis             APP
#   409 2024-12-01 23:35:29           13.0            metrics             APP
#   410 2024-12-01 23:39:47          271.0      code-analysis             APP
#   411 2024-12-01 23:34:16          267.0      code-analysis             APP
#   412 2024-12-01 21:50:03          265.0      code-analysis             APP
#   413 2024-12-01 21:34:43           12.0            metrics             APP
#   414 2024-12-01 21:39:07          276.0      code-analysis             APP
#   415 2024-12-01 21:24:35          272.0      code-analysis             APP
#   416 2024-12-01 21:21:33          266.0      code-analysis             APP
#   417 2024-12-01 21:09:14          274.0      code-analysis             APP
#   418 2024-11-19 00:19:35           17.0            metrics             APP
#   419 2024-11-19 00:18:46          265.0      code-analysis             APP
#   420 2024-11-18 23:53:56           13.0            metrics             APP
#   421 2024-11-18 23:41:38          279.0      code-analysis             APP
#   422 2024-11-18 23:37:49          284.0      code-analysis             APP  },
#  {'name': 'StudioMaker',
#   'df':      Workflow_run ID Conclusion      Author          Created at  \
#   94       12112358389    failure  dartmol203 2024-12-02 03:53:43
#   103 2024-11-17 18:10:23          122.0      code-analysis     StudioMaker
#   104 2024-11-16 21:25:34           14.0            metrics     StudioMaker
#   105 2024-11-16 21:27:07          107.0      code-analysis     StudioMaker
#   106 2024-11-16 21:25:34           14.0             deploy     StudioMaker
#   107 2024-11-16 21:24:02          113.0      code-analysis     StudioMaker
#   108 2024-11-16 21:12:01           21.0            metrics     StudioMaker
#   109 2024-11-16 21:11:53           13.0             deploy     StudioMaker
#   110 2024-11-16 21:13:36          116.0      code-analysis     StudioMaker
#   111 2024-11-16 21:10:41          107.0      code-analysis     StudioMaker
#   384 2024-12-02 23:56:07           10.0            metrics     StudioMaker
#   385 2024-12-02 23:56:12           15.0             deploy     StudioMaker
#   386 2024-12-02 23:56:05            8.0      code-analysis     StudioMaker
#   387 2024-12-02 23:47:04          106.0      code-analysis     StudioMaker
#   388 2024-12-02 03:53:55           12.0             deploy     StudioMaker
#   389 2024-12-02 03:55:29          106.0      code-analysis     StudioMaker
#   390 2024-12-02 03:54:07           24.0            metrics     StudioMaker
#   391 2024-12-02 03:53:36          129.0      code-analysis     StudioMaker
#   392 2024-11-17 18:17:16           20.0            metrics     StudioMaker
#   393 2024-11-17 18:18:49          114.0      code-analysis     StudioMaker
#   394 2024-11-17 18:17:14           19.0             deploy     StudioMaker
#   395 2024-11-17 18:12:54          110.0      code-analysis     StudioMaker
#   396 2024-11-17 18:08:38           16.0             deploy     StudioMaker
#   397 2024-11-17 18:10:23          122.0      code-analysis     StudioMaker
#   398 2024-11-16 21:25:34           14.0            metrics     StudioMaker
#   399 2024-11-16 21:27:07          107.0      code-analysis     StudioMaker
#   400 2024-11-16 21:25:34           14.0             deploy     StudioMaker
#   401 2024-11-16 21:24:02          113.0      code-analysis     StudioMaker
#   402 2024-11-16 21:12:01           21.0            metrics     StudioMaker
#   403 2024-11-16 21:11:53           13.0             deploy     StudioMaker
#   404 2024-11-16 21:13:36          116.0      code-analysis     StudioMaker
#   405 2024-11-16 21:10:41          107.0      code-analysis     StudioMaker  },
#  {'name': 'UserService',
#   'df':      Workflow_run ID Conclusion      Author          Created at  \
#   301      12130111660       None  gabrielm2q 2024-12-02 23:53:50
#   302      12130111639       None  gabrielm2q 2024-12-02 23:53:50
#   303      12130111638    failure  gabrielm2q 2024-12-02 23:53:50
#   304      12130088510    success  dartmol203 2024-12-02 23:51:32
#   305      12112284471    success  dartmol203 2024-12-02 03:45:27
#   306      12112284464    success  dartmol203 2024-12-02 03:45:27
#   307      12112284462    failure  dartmol203 2024-12-02 03:45:27
#   308      12112259313    success  dartmol203 2024-12-02 03:42:43
#   309      12109182625    failure  dartmol203 2024-12-01 21:26:44
#   310      12109182624    success  dartmol203 2024-12-01 21:26:44
#   311      12109168173    failure  dartmol203 2024-12-01 21:24:46
#   312      12109168166    success  dartmol203 2024-12-01 21:24:46
#   313      11999859518    failure  dartmol203 2024-11-24 21:48:04
#   314      11999859512    success  dartmol203 2024-11-24 21:48:04
#   316 2024-11-23 19:10:06          130.0      code-analysis     UserService
#   317 2024-11-17 18:06:55           20.0             deploy     UserService
#   318 2024-11-17 18:08:43          128.0      code-analysis     UserService
#   319 2024-11-17 18:06:51           16.0            metrics     UserService
#   320 2024-11-17 18:00:58          121.0      code-analysis     UserService
#   321 2024-11-17 18:00:04          120.0      code-analysis     UserService
#   322 2024-11-17 17:55:55          138.0      code-analysis     UserService
#   323 2024-11-16 21:40:03           15.0            metrics     UserService
#   324 2024-11-16 21:41:47          120.0      code-analysis     UserService
#   325 2024-11-16 21:40:01           14.0             deploy     UserService
#   326 2024-11-16 21:39:21          138.0      code-analysis     UserService
#   362 2024-12-02 03:45:34            7.0      code-analysis     UserService
#   363 2024-12-02 03:45:36            9.0            metrics     UserService
#   364 2024-12-02 03:45:40           13.0             deploy     UserService
#   365 2024-12-02 03:44:52          129.0      code-analysis     UserService
#   366 2024-12-01 21:26:57           13.0             deploy     UserService
#   367 2024-12-01 21:28:56          132.0      code-analysis     UserService
#   368 2024-12-01 21:24:59           13.0             deploy     UserService
#   369 2024-12-01 21:26:54          128.0      code-analysis     UserService
#   370 2024-11-24 21:48:21           17.0             deploy     UserService
#   371 2024-11-24 21:50:08          124.0      code-analysis     UserService
#   372 2024-11-24 21:48:22           18.0            metrics     UserService
#   373 2024-11-23 19:10:06          130.0      code-analysis     UserService
#   374 2024-11-17 18:06:55           20.0             deploy     UserService
#   375 2024-11-17 18:08:43          128.0      code-analysis     UserService
#   376 2024-11-17 18:06:51           16.0            metrics     UserService
#   377 2024-11-17 18:00:58          121.0      code-analysis     UserService
#   378 2024-11-17 18:00:04          120.0      code-analysis     UserService
#   379 2024-11-17 17:55:55          138.0      code-analysis     UserService
#   380 2024-11-16 21:40:03           15.0            metrics     UserService
#   381 2024-11-16 21:41:47          120.0      code-analysis     UserService
#   382 2024-11-16 21:40:01           14.0             deploy     UserService
#   383 2024-11-16 21:39:21          138.0      code-analysis     UserService  },
#  {'name': 'Frontend',
#   'df':      Workflow_run ID Conclusion      Author          Created at  \
#   112      12130122028    failure  gabrielm2q 2024-12-02 23:54:53
#   113      12130122018       None  gabrielm2q 2024-12-02 23:54:53
#   114      12130122013       None  gabrielm2q 2024-12-02 23:54:53
#   115      12129953546    failure  dartmol203 2024-12-02 23:39:10
#   116      12118430174    failure  dartmol203 2024-12-02 11:30:59
#   117      12118391051    failure  dartmol203 2024-12-02 11:28:37
#   118      12118354276    failure  dartmol203 2024-12-02 11:26:19
#   119      12112944235    failure  dartmol203 2024-12-02 04:56:46
#   120      12112944221    failure  dartmol203 2024-12-02 04:56:46
#   121      12112944216    success  dartmol203 2024-12-02 04:56:46
#   122      12112899247    failure  dartmol203 2024-12-02 04:51:25
#   123      12112863444    failure  dartmol203 2024-12-02 04:47:53
#   124      12112714196    failure  dartmol203 2024-12-02 04:31:32
#   125      12112658990    failure  dartmol203 2024-12-02 04:25:28
#   126      12112491296    failure  dartmol203 2024-12-02 04:07:41
#   127      12112433452    failure  dartmol203 2024-12-02 04:02:04
#   120 2024-12-02 04:57:03           17.0    deploy-vm-azure        Frontend
#   121 2024-12-02 04:57:07           21.0            metrics        Frontend
#   122 2024-12-02 04:54:22          177.0      code-analysis        Frontend
#   123 2024-12-02 04:51:03          190.0      code-analysis        Frontend
#   124 2024-12-02 04:34:45          193.0      code-analysis        Frontend
#   125 2024-12-02 04:28:25          177.0      code-analysis        Frontend
#   126 2024-12-02 04:10:52          191.0      code-analysis        Frontend
#   127 2024-12-02 04:04:13          129.0      code-analysis        Frontend
#   128 2024-12-02 04:01:41            2.0            metrics        Frontend
#   129 2024-12-01 20:46:36          153.0      code-analysis        Frontend
#   130 2024-11-17 18:24:53           17.0    deploy-vm-azure        Frontend
#   131 2024-11-17 18:27:04          148.0      code-analysis        Frontend
#   132 2024-11-17 18:24:55           19.0            metrics        Frontend
#   133 2024-11-17 18:23:07          121.0      code-analysis        Frontend
#   134 2024-11-17 18:21:57          129.0      code-analysis        Frontend
#   135 2024-11-16 21:39:37          134.0      code-analysis        Frontend
#   136 2024-11-16 21:37:35           12.0    deploy-vm-azure        Frontend
#   137 2024-11-16 21:37:42           19.0            metrics        Frontend
#   138 2024-11-16 21:37:06          296.0      code-analysis        Frontend
#   139 2024-11-16 21:28:01           16.0            metrics        Frontend
#   140 2024-11-16 21:27:56           11.0    deploy-vm-azure        Frontend
#   141 2024-11-16 21:30:02          137.0      code-analysis        Frontend
#   142 2024-11-16 21:07:18          132.0      code-analysis        Frontend
#   277 2024-12-02 04:56:53            7.0      code-analysis        Frontend
#   278 2024-12-02 04:56:54            8.0    deploy-vm-azure        Frontend
#   279 2024-12-02 04:56:54            8.0            metrics        Frontend
#   280 2024-12-02 04:54:22          177.0      code-analysis        Frontend
#   281 2024-12-02 04:51:03          190.0      code-analysis        Frontend
#   282 2024-12-02 04:34:45          193.0      code-analysis        Frontend
#   283 2024-12-02 04:28:25          177.0      code-analysis        Frontend
#   284 2024-12-02 04:10:52          191.0      code-analysis        Frontend
#   285 2024-12-02 04:04:13          129.0      code-analysis        Frontend
#   286 2024-12-02 04:01:41            2.0            metrics        Frontend
#   287 2024-12-01 20:46:36          153.0      code-analysis        Frontend
#   288 2024-11-17 18:24:53           17.0    deploy-vm-azure        Frontend
#   289 2024-11-17 18:27:04          148.0      code-analysis        Frontend
#   290 2024-11-17 18:24:55           19.0            metrics        Frontend
#   291 2024-11-17 18:23:07          121.0      code-analysis        Frontend
#   292 2024-11-17 18:21:57          129.0      code-analysis        Frontend
#   293 2024-11-16 21:39:37          134.0      code-analysis        Frontend
#   294 2024-11-16 21:37:35           12.0    deploy-vm-azure        Frontend
#   295 2024-11-16 21:37:42           19.0            metrics        Frontend
#   296 2024-11-16 21:37:06          296.0      code-analysis        Frontend
#   297 2024-11-16 21:28:01           16.0            metrics        Frontend
#   298 2024-11-16 21:27:56           11.0    deploy-vm-azure        Frontend
#   299 2024-11-16 21:30:02          137.0      code-analysis        Frontend
#   300 2024-11-16 21:07:18          132.0      code-analysis        Frontend  }]

# %% [markdown]
# # Create Issues DataFrame

# %% [markdown]
# #### Extract Issues Data

# %%
def get_issues_data():
    for json_path in data_issues:
        dados = unmarshall(json_path)
        table_data = []
        for run in dados:
            created_at = run["created_at"]
            closed_at  = run["closed_at"]
            number = run["number"]
            title = run["title"]
            
            table_data.append({
                "Created at": created_at,
                "Closed at": closed_at,
                "Issue Number": number,
                "Issue Title": title,
            })

    return table_data

# %% [markdown]
# #### Generate Issues DataFrame

# %%
def generate_issues_df(data: List[dict]) -> pd.DataFrame:
    df = pd.DataFrame(data)

    df['Created at'] = pd.to_datetime(df['Created at'], format='%Y-%m-%dT%H:%M:%SZ')

    df['Closed at'] = pd.to_datetime(df['Closed at'], format='%Y-%m-%dT%H:%M:%SZ')
    
    return df

# %%
issues_df = generate_issues_df(get_issues_data())
issues_df.head()
# Out:
#            Created at Closed at  Issue Number  \
# 0 2024-12-02 22:55:58       NaT            91
# 1 2024-12-02 22:51:53       NaT            90
# 2 2024-12-02 22:51:01       NaT            89
# 3 2024-12-02 22:47:41       NaT            88
# 4 2024-12-02 22:47:15       NaT            87
#
#                                          Issue Title
# 0              Gestão de Conhecimentos e Pareamentos
# 1         Planejamento de Riscos, Custos e Qualidade
# 2  Configuração do Repositório de Acordo com Padr...
# 3      Atualizar Documento de Arquitetura do Projeto
# 4        Documentar Agenda de Trabalho e Ferramentas

# %% [markdown]
# # Quality Aspect - Productivity

# %% [markdown]
# ## Factor - Testing Performance

# %% [markdown]
# ### CI Feedback Time

# %%
def ci_feedback_time(df: pd.DataFrame):
    feedback_times = []
    authors_feedback_times = {}
    ci_feedback_times = []

    # Filter for builds workflow runs only
    df_filtered = df[df["Workflow .YML Name"] == build_yml_name].copy()

    for run in df_filtered.index:
        updated_at = df["Updated at"][run]
        created_at = df["Created at"][run]
        feedback_time = (updated_at - created_at).total_seconds()
        feedback_times.append(feedback_time)

    ci_feedback_time = sum(feedback_times) / len(feedback_times)
    df_filtered.loc[:, "Ci Feedback Time"] = ci_feedback_time

    return df_filtered

# %% [markdown]
# ### Extra: Count of Successes and Failures Workflows

# %%
def count_success_failure_workflow_runs(df: pd.DataFrame):
    counts = df['Conclusion'].value_counts()

    num_failures = counts.get('failure', 0)
    num_successes = counts.get('success', 0)

    return num_failures, num_successes

# %% [markdown]
# ## Factor - Issues' Velocity

# %% [markdown]
# ### Team Throughput

# %%
def team_throughput(df: pd.DataFrame, start_date: str, end_date: str):
    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)
    
    df_date_filtered = df[(df['Created at'] >= start_date) & (df['Closed at'] <= end_date + pd.Timedelta(days=1))]
    df_created = df[(df['Created at'] >= start_date)]

    return len(df_date_filtered[df_date_filtered["Closed at"].notnull()]), len(df_created)

# %% [markdown]
# ## Calculate measures (workflow runs) for each repository
#
# Filter the dataset with the set dates in the notebook's beginning.

# %%
def create_metrics_df(start_date: str, end_date: str) -> pd.DataFrame:
    
    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)

    m1_list = []
    m2_list = []
    m3_list = []

    repository_list = []
    version_list = []

    for repo_info in repos_dataframes:
        repo_df = repo_info["df"]

        repo_df['Updated at'] = pd.to_datetime(repo_df['Updated at'])

        # Filter the selected date range
        df_date_filtered = repo_df[(repo_df['Updated at'] >= start_date) & (repo_df['Updated at'] <= end_date + pd.Timedelta(days=1))]

        try:
            m1_list.append(ci_feedback_time(df_date_filtered))
        except Exception:
            m1_list.append(0)

        try:
            m2_list.append(count_success_failure_workflow_runs(df_date_filtered))
        except Exception:
            m2_list.append(0)

        repository_list.append(repo_info['name'])

    return m1_list, m2_list, repository_list

# %%
m1_list, m2_list, repository_list = create_metrics_df(start_date_workflow_runs, end_date_workflow_runs)
# Out:
# /tmp/ipykernel_368068/3981976724.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   repo_df['Updated at'] = pd.to_datetime(repo_df['Updated at'])
# /tmp/ipykernel_368068/3981976724.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   repo_df['Updated at'] = pd.to_datetime(repo_df['Updated at'])
# /tmp/ipykernel_368068/3981976724.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   repo_df['Updated at'] = pd.to_datetime(repo_df['Updated at'])
# /tmp/ipykernel_368068/3981976724.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   repo_df['Updated at'] = pd.to_datetime(repo_df['Updated at'])

# %% [markdown]
# ## Plotting Metrics Functions

# %% [markdown]
# ### Generate CI Feedback Time Plots

# %%
def ci_feedback_time_plots(df: pd.DataFrame, repo_name: str):
    temp = df[['Created at', 'Ci Feedback Time']]
    dates = temp.groupby(['Created at']).mean().reset_index()
    dates['Created at'] = pd.to_datetime(dates['Created at'])

    plt.figure(figsize=(15, 7))
    plt.plot(range(len(dates)), dates['Ci Feedback Time'], marker='o', color='b', label='Feedback Time')
    plt.xlabel("Created at")
    plt.ylabel("CI FeedBack Time")
    plt.title(f"CI FeedBack Time By Creation Date - {repo_name}")
    plt.xticks(range(len(dates)), dates['Created at'].dt.strftime('%Y-%m-%d'), rotation=45)
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Generate Count of Successes and Failures Workflows Plots

# %%
def count_sucess_failure_workflow_plot(data: list, repo_name: str):
    labels = ["Success", "Failure"]
    sizes = [data[1], data[0]]
    plt.figure(figsize=(15, 7))
    colors = ['lightgreen', 'crimson']
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors)
    plt.title(f"Count of Workflows Runs Success and Failures - {repo_name}")
    plt.legend(labels, loc='best')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Generate Throughput Pie Plot

# %%
def team_throughput_plot(data: list):
    labels = ["Closed Issues", "Not Closed Issues"]
    sizes = [data[0], data[1]-data[0]]
    plt.figure(figsize=(15, 7))
    colors = ['lightgreen', 'crimson']
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors)
    plt.title("Team Throughput Over a Date Range")
    plt.legend(labels, loc='best')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Data Visualization
#
# In this area you will need to plot the metrics of each repository in the selected date range.

# %%
print(repository_list)
# Out:
# ['APP', 'StudioMaker', 'UserService', 'Frontend']

# %%
for repo in range(len(repository_list)):
    ci_feedback_time_plots(m1_list[repo], repository_list[repo])
    count_sucess_failure_workflow_plot(m2_list[repo], repository_list[repo])

# %%
team_throughput_plot(team_throughput(issues_df, start_date_issues, end_date_issues))
